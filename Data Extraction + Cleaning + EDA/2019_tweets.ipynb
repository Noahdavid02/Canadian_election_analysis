# %%
# import tweepy
import tweepy as tw
# your Twitter API key and API secret
my_api_key = "XXXXX"
my_api_secret = "XXXXXXX"
# authenticate
auth = tw.OAuthHandler(my_api_key, my_api_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_query = "#elxn43 OR #cdnpoli OR #ItsOurVote -filter:retweets"

# %%
# get tweets from the API
tweets = tw.Cursor(api.search_tweets,
              q=search_query,
              lang="en",
              since="2019-05-01").items(500)
# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Total Tweets fetched: 500

# %%
import pandas as pd

# intialize the dataframe
tweets_df = pd.DataFrame()

# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)

# show the dataframe
tweets_df.head()
# Out:
#                      user_name            user_location  \
# 0               SillyWorkMedia            Vancouver, BC
# 1             Peter V. Tretter  Barrie, Ontario, Canada
# 2          Fight Back w/ Libby
# 3             peter’s rabbit 🍃            Turtle Island
# 4  KaveLiveLifeKlimateIsKaotic
#
#                                     user_description  user_verified  \
# 0  Observer in Vancouver Real Estate, US Stocks, ...          False
# 1  President & CEO of Journey to Diversity Workpl...          False
# 2  Weekdays from noon-1pm. Make your voice heard ...          False
# 3  A collector of truths. Natale biologicum femin...          False
# 4  Climate is not a problem. Forced global social...          False
#
#                        date  \
# 0 2022-05-30 15:14:49+00:00
# 1 2022-05-30 15:14:17+00:00
# 2 2022-05-30 15:14:12+00:00
# 3 2022-05-30 15:13:03+00:00
# 4 2022-05-30 15:12:58+00:00
#
#                                                 text   hashtags  \
# 0  Isn't it every system is broken in Canada?\nMi...  [cdnpoli]
# 1  There were telltale signs of money laundering....       None
# 2  AT 12:45 ET: @JaneBrownNews is joined by Peter...       None
# 3  @EmpireinWinter this is what the WEF/UN/WHO (a...       None
# 4  When your own gov't creates a situation that e...       None
#
#                 source
# 0  Twitter for Android
# 1               Buffer
# 2      Twitter Web App
# 3   Twitter for iPhone
# 4  Twitter for Android

# %%
tweets_df.to_csv(r'C:\Users\JEBIN GEORGE\Desktop\Sentiment Analysis\2019_tweets.csv')
